# %%
what the hell dude
# Out:
#   Cell In[1], line 1
#     what the hell dude
#          ^
# SyntaxError: invalid syntax

# %%
print(123)
# Out:
# 123

# %%
print("Hello RunIt user")
# Out:
# Hello RunIt user
